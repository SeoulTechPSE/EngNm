# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
#plt.ion()

# %%
import pandas as pd
import numpy as np

# %%
pd.Series(np.sin(np.arange(0, 10, 0.1))).plot() # plot window appears
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline

# %%
pd.Series(np.sin(np.arange(0, 10, 0.1))).plot() # plot window appears
plt.show()

# %%
# %matplotlib notebook

# %%
pd.Series(np.sin(np.arange(0, 10, 0.1))).plot() # plot window appears
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

# %%
pd.Series(np.sin(np.arange(0, 10, 0.1))).plot() # plot window appears
plt.show()

# %%
import matplotlib as mpl
mpl.use('qt5agg')
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
pd.Series(np.sin(np.arange(0, 10, 0.1))).plot() # plot window appears
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
